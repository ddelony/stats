# %% [markdown]
# Plot of a normal distribution pdf.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline

# %% [markdown]
# Set up an x axis with NumPy and plot with Matplotlib.

# %%
x = np.arange(-4,4,.01)
plt.plot(x,norm.pdf(x))
